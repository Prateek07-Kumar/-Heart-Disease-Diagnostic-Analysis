# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading Dataset

# %%
df=pd.read_csv("D:\heart_disease_dataset.csv")
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope      ca  thal  num
# 0        3       0     6    0
# ...

# %%
# showing total rows and columns 

df.shape
# Out:
# (303, 14)

# %%
# showing top five rows 
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
# showing Last five rows
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope      ca  thal  num
# 298      2       0     7    1
# 299      2       2     7    1
# 300      2       1     7    1
# 301      2       1     3    1
# 302      1 -100000     3    0

# %%
# printing information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# printing all columns name
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
# checking null values

df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
# printing statistical summary of dataset

df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660
# std      0.994971   22.875003    0.469794    1.161075    0.616226
# ...

# %%
# checking duplicated values

df.duplicated().sum()
# Out:
# 0

# %%
# printing correlation of data

df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# sex      -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fbs       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# ca        0.085766 -0.079361  0.019134 -0.010263  0.068128 -0.032997
# thal      0.017545  0.031518 -0.028985  0.017149  0.057866 -0.080552
# ...

# %% [markdown]
# # Age

# %%
df.age.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0      63
# 1      67
# 2      67
# 3      37
# 4      41
#        ..
# 298    45
# 299    68
# 300    57
# 301    57
# 302    38
# Name: age, Length: 303, dtype: int64>

# %%
# checking distribution of age columns

df.age.plot(kind='kde',figsize=(8,6),legend=True, title="Age Distribution")
plt.show()

# %%
# checking the outlier of age columns


df.age.plot(kind='box',figsize=(8,6),legend=True, title="Age box Visualization")
plt.show()

# %%
# minimum age

df.age.min()
# Out:
# 29

# %%
# mazimum age
df.age.max()
# Out:
# 77

# %%
# Mean of Age

df.age.mean()
# Out:
# 54.43894389438944

# %%
# Median Age

df.age.median()
# Out:
# 56.0

# %%
# 25 % of People come under 48 age
df.age.quantile(0.25)
# Out:
# 48.0

# %%
# 25 % of People come under 61 age
df.age.quantile(0.75)
# Out:
# 61.0

# %% [markdown]
# # Gender Column

# %%
df.sex.value_counts()
# Out:
# 1    206
# 0     97
# Name: sex, dtype: int64

# %% [markdown]
# Male = 1
#
# Female = 0

# %%
df.sex.value_counts().plot(kind='pie',figsize=(10,8),autopct='%1.0f%%',legend=True,title='Gender Pie Chart')
plt.show()

# %%
df.sex.value_counts().plot(kind='bar',legend=True,title='Gender Pie Chart',figsize=(10,8),color=['red','orange'])
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %% [markdown]
# # Chest Pain Colun

# %%
df.cp.value_counts()
# Out:
# 4    144
# 3     86
# 2     50
# 1     23
# Name: cp, dtype: int64

# %% [markdown]
# #Value 1: Stable
# #Value 2: Unstable
# #Value 3: Microvascular
# #Value 4: Variant

# %%
df.cp.value_counts().plot(kind='pie',figsize=(10,8),autopct='%1.0f%%',legend=True,title='Chest Pain Chart')
plt.show()

# %%
df.cp.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title='Chest pain Experience Bar Chart',color = ['green','blue','orange','red'])
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %% [markdown]
# # trestbps column : The person's resting blood pressure

# %%
df.trestbps.unique()
# Out:
# array([145, 160, 120, 130, 140, 172, 150, 110, 132, 117, 135, 112, 105,
#        124, 125, 142, 128, 170, 155, 104, 180, 138, 108, 134, 122, 115,
#        118, 100, 200,  94, 165, 102, 152, 101, 126, 174, 148, 178, 158,
#        192, 129, 144, 123, 136, 146, 106, 156, 154, 114, 164], dtype=int64)

# %% [markdown]
# The person's resting blood pressure (mm Hg on admission to the hospital)

# %%
df.trestbps.plot(kind='kde',figsize=(10,8),legend=True,title='Blood Pressure Pie Chat')
plt.show()

# %%
df.trestbps.plot(kind='box',figsize=(10,8),legend=True,title='Blood Pressure Boxplot')
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
df.chol.unique()
# Out:
# array([233, 286, 229, 250, 204, 236, 268, 354, 254, 203, 192, 294, 256,
#        263, 199, 168, 239, 275, 266, 211, 283, 284, 224, 206, 219, 340,
#        226, 247, 167, 230, 335, 234, 177, 276, 353, 243, 225, 302, 212,
#        330, 175, 417, 197, 198, 290, 253, 172, 273, 213, 305, 216, 304,
#        188, 282, 185, 232, 326, 231, 269, 267, 248, 360, 258, 308, 245,
#        270, 208, 264, 321, 274, 325, 235, 257, 164, 141, 252, 255, 201,
#        222, 260, 182, 303, 265, 309, 307, 249, 186, 341, 183, 407, 217,
#        288, 220, 209, 227, 261, 174, 281, 221, 205, 240, 289, 318, 298,
#        564, 246, 322, 299, 300, 293, 277, 214, 207, 223, 160, 394, 184,
#        315, 409, 244, 195, 196, 126, 313, 259, 200, 262, 215, 228, 193,
#        271, 210, 327, 149, 295, 306, 178, 237, 218, 242, 319, 166, 180,
#        311, 278, 342, 169, 187, 157, 176, 241, 131], dtype=int64)

# %%
df.chol.plot(kind='kde',figsize=(10,8),legend=True,title='Cholestrol Dristribution')
plt.show()

# %%
df.chol.plot(kind='box',figsize=(10,8),legend=True,title='Boxplot of Cholestrol Chart')
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %% [markdown]
# # Fasting Blood Sugar

# %%
df.fbs.value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %% [markdown]
# The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)

# %%
df.fbs.value_counts().plot(kind='pie',autopct='%1.0f%%',figsize=(10,8),legend=True,title='Fasting Blood Sugar Chart')
plt.show()

# %%
df.fbs.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title='Fasting Blood Sugar Bar Chart',color=['blue','red'])
plt.show()

# %% [markdown]
# # Electrocardiographic Column

# %%
df.restecg.value_counts()
# Out:
# 0    151
# 2    148
# 1      4
# Name: restecg, dtype: int64

# %% [markdown]
# Resting electrocardiographic measurement
#
# 0 = normal
# 1 = having ST-T wave abnormality
# 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria

# %%
df.restecg.value_counts().plot(kind='pie',autopct='%1.0f%%',figsize=(10,8),legend=True,title=('Electrocardiogram Pie Chart'))
plt.show()

# %%
df.restecg.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title=('Electrocardiogram Box Chart'),color=['blue','orange','red'])
plt.show()

# %% [markdown]
# # Heart Rate Column

# %%
df.thalach.unique()
# Out:
# array([150, 108, 129, 187, 172, 178, 160, 163, 147, 155, 148, 153, 142,
#        173, 162, 174, 168, 139, 171, 144, 132, 158, 114, 151, 161, 179,
#        120, 112, 137, 157, 169, 165, 123, 128, 152, 140, 188, 109, 125,
#        131, 170, 113,  99, 177, 141, 180, 111, 143, 182, 156, 115, 149,
#        145, 146, 175, 186, 185, 159, 130, 190, 136,  97, 127, 154, 133,
#        126, 202, 103, 166, 164, 184, 124, 122,  96, 138,  88, 105, 194,
#        195, 106, 167,  95, 192, 117, 121, 116,  71, 118, 181, 134,  90],
#       dtype=int64)

# %% [markdown]
# thalach: The person's maximum heart rate achieved

# %%
df.thalach.plot(kind='kde',figsize=(10,8),legend=True,title=('Heart rate Distribution'))
plt.show()

# %%
df.thalach.plot(kind='box',figsize=(10,8),legend=True,title=('Heart rate boxplot Distribution'))
plt.show()

# %% [markdown]
# # Exercise Induced Angina Column

# %%
df.exang.value_counts()
# Out:
# 0    204
# 1     99
# Name: exang, dtype: int64

# %% [markdown]
# exang: Exercise induced angina (1 = yes; 0 = no)

# %%
df.exang.value_counts().plot(kind='pie',figsize=(10,8),autopct='%1.0f%%',legend=True,title=('Angina Pie Chart'))
plt.show()

# %%
df.exang.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title=('Angina BoxPlot'),color=['blue','green'])
plt.show()

# %% [markdown]
# # oldpeak : ST Depression Column

# %%
df.oldpeak.unique()
# Out:
# array([2.3, 1.5, 2.6, 3.5, 1.4, 0.8, 3.6, 0.6, 3.1, 0.4, 1.3, 0. , 0.5,
#        1.6, 1. , 1.2, 0.2, 1.8, 3.2, 2.4, 2. , 2.5, 2.2, 2.8, 3. , 3.4,
#        6.2, 4. , 5.6, 2.9, 0.1, 2.1, 1.9, 4.2, 0.9, 1.1, 3.8, 0.7, 0.3,
#        4.4])

# %% [markdown]
# oldpeak: ST depression induced by exercise relative to rest

# %%
df.oldpeak.plot(kind='kde',figsize=(10,8),legend=True,title=('ST Depression Distribution'))
plt.show()

# %%
df.oldpeak.plot(kind='box',figsize=(10,8),legend=True,title=('ST Depression BoxPlot Distribution'))
plt.show()

# %% [markdown]
# # Slope Column

# %%
df.slope.value_counts()
# Out:
# 1    142
# 2    140
# 3     21
# Name: slope, dtype: int64

# %% [markdown]
# The slope of the peak exercise ST segment
#
# Value 1: Upsloping
#
# Value 2: Flat
#
# Value 3: Downsloping

# %%
df.slope.value_counts().plot(kind='pie',autopct='%1.0f%%',figsize=(10,8),legend=True,title=('Slope of Pie Chart'))
plt.show()

# %%
df.slope.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title=('Slope of BoxPlot Chart'),color=['blue','green','yellow'])
plt.show()

# %% [markdown]
# # ca : Major Vessels Column

# %%
df.ca.value_counts()
# Out:
#  0         176
#  1          65
#  2          38
#  3          20
# -100000      4
# Name: ca, dtype: int64

# %% [markdown]
# The number of major vessels (0-3)

# %%
df.ca = df.ca.replace(-100000,3)

# %%
df.ca.value_counts()
# Out:
# 0    176
# 1     65
# 2     38
# 3     24
# Name: ca, dtype: int64

# %%
df.ca.value_counts().plot(kind='pie',autopct='%1.0f%%',figsize=(10,8),legend=True,title=('Majore Vassels of Pie Chart'))
plt.show()

# %%
df.ca.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title=('Major Vassels of BoxPlot'),color=['red','blue','yellow','green'])
plt.show()

# %% [markdown]
# # Thalassemia Column

# %%
df.thal.value_counts()
# Out:
#  3         166
#  7         117
#  6          18
# -100000      2
# Name: thal, dtype: int64

# %%
df.thal=df.thal.replace(-100000,6)

# %%
df.thal.value_counts()
# Out:
# 3    166
# 7    117
# 6     20
# Name: thal, dtype: int64

# %% [markdown]
# A blood disorder called thalassemia
#
# 3 = normal
#
# 6 = fixed defect
#
# 7 = reversable defect

# %%
df.thal.value_counts().plot(kind='pie',autopct='%1.0f%%',figsize=(10,8),legend=True,title=('Thalassemia of Pie Chart'))
plt.show()

# %%
df.thal.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title=('Thalassemia of BoxPlot'),color=['red','blue','yellow'])
plt.show()

# %% [markdown]
# # Heart Disease Column

# %%
df.num.value_counts()
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64

# %% [markdown]
# Heart Disease
#
# 0 = no
#
# 1 = yes

# %%
df.num.value_counts().plot(kind='pie',autopct='%1.0f%%',figsize=(10,8),legend=True,title=('Heart Disease Pie Chart'))
plt.show()

# %%
df.num.value_counts().plot(kind='bar',figsize=(10,8),legend=True,title=('Thalassemia of Pie Chart'),color=['red','orange'])
plt.show()

# %% [markdown]
# There are thirteen features in Dataset
#
# * age: The person's age in years
#
# * sex: The person's sex (1 = male, 0 = female)
#
# * cp: The chest pain experienced Value 1: Stable Value 2: Unstable Value 3: Microvascular Value 4: Variant
#
# * trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# * chol: The person's cholesterol measurement in mg/dl
#
# * fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# * restecg: Resting electrocardiographic measurement 0 = normal 1 = having ST-T wave abnormality 2 = showing probable or   definite left ventricular hypertrophy by Estes' criteria
#
# * thalach: The person's maximum heart rate achieved
#
# * exang: Exercise induced angina (1 = yes; 0 = no)
#
# * oldpeak: ST depression induced by exercise relative to rest
#
# * slope: the slope of the peak exercise ST segment Value 1: Upsloping Value 2: Flat Value 3: Downsloping
#
# * ca: The number of major vessels (0-3)
#
# * thal: A blood disorder called thalassemia 3 = normal 6 = fixed defect 7 = reversable defect
#
# * num: Heart disease 0 = no 1 = yes

# %%
df.head(1)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
#
#    ca  thal  num
# 0   0     6    0

# %%
# creating function to convert numberical to categorical data


# age column

def ages(column):
    if column <35:
        return "Youngster"
    elif column >=35 and column <60:
        return "Seniour Citizens"
    else:
        return "Super Senior Citizens"
        
# Sex Column

def sex_(column):
    if column==1:
        return "Male"
    else:
        return "Female"
    
# CP Column

def cp_(column):
    if column==1:
        return "Stable"
    elif column==2:
        return "Unstable"
    elif column==3:
        return "Microvascular"
    else:
        return "Variants"
    

# trestbps Column
def exang_(column):
    if column==1:
        return "Yes"
    else:
        return "No"
    
# Slope Column
def slope_(column):
    if column==1:
        return "Unsloping"
    elif column==2:
        return "Flat"
    else:
        return "Downsloping"
    
# thal column
def thal_(column):
    if column==3:
        return "Normal"
    elif column==6:
        return "Fixed Defect"
    else:
        return "Reversable Defect"
# num column

def num_(column):
    if column==1:
        return "Presence"
    else:
        return "Absence"

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
df1=df.copy()

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
df1["ageC"]=df1["age"].apply(ages)
df1["sexC"]=df1["sex"].apply(sex_)
df1["cpC"]=df1["cp"].apply(cp_)
df1["exangC"]=df1["exang"].apply(exang_)
df1["slopeC"]=df1["slope"].apply(slope_)
df1["thalC"]=df1["thal"].apply(thal_)
df1["numC"]=df1["num"].apply(num_)

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  ...  \
# 0   63    1   1       145   233    1        2      150      0      2.3  ...
# 1   67    1   4       160   286    0        2      108      1      1.5  ...
# 2   67    1   4       120   229    0        2      129      1      2.6  ...
# 3   37    1   3       130   250    0        0      187      0      3.5  ...
# 4   41    0   2       130   204    0        2      172      0      1.4  ...
#
#    ca  thal  num                   ageC    sexC            cpC exangC  \
# 0   0     6    0  Super Senior Citizens    Male         Stable     No
# 1   3     3    1  Super Senior Citizens    Male       Variants    Yes
# 2   2     7    1  Super Senior Citizens    Male       Variants    Yes
# 3   0     3    0       Seniour Citizens    Male  Microvascular     No
# 4   0     3    0       Seniour Citizens  Female       Unstable     No
#
#         slopeC              thalC      numC
# ...

# %%
df = df[]

# %% [markdown]
# # Univariate Analysis

# %%
df1.ageC.value_counts()
# Out:
# Seniour Citizens         209
# Super Senior Citizens     91
# Youngster                  3
# Name: ageC, dtype: int64

# %%
sns.countplot(x=df1.ageC)
# plt.figure(figsize=(25,20))
plt.show()

# %%
df1.ageC.value_counts().plot(kind="pie",autopct=("%1.1f%%"),explode=(0,0,0.1),shadow=True,figsize=(10,8))
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.countplot(x='age',data=df)
plt.title('Population Age',fontsize=25)
plt.xlabel('Age',fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.show()

# %%
df1.sexC.value_counts()
# Out:
# Male      206
# Female     97
# Name: sexC, dtype: int64

# %%
sns.countplot(x=df1.sex)
plt.show()

# %%
df1.sexC.value_counts().plot(kind="pie",autopct="%1.1f%%",shadow=True,figsize=(10,8))
plt.show()

# %%
df1.cpC.value_counts()
# Out:
# Variants         144
# Microvascular     86
# Unstable          50
# Stable            23
# Name: cpC, dtype: int64

# %%
sns.countplot(x=df1.cpC)
plt.show()

# %%
df1.cpC.value_counts().plot(kind="pie",autopct=("%1.1f%%"),shadow=True,figsize=(10,8))
plt.show()

# %%
df1.exangC.value_counts()
# Out:
# No     204
# Yes     99
# Name: exangC, dtype: int64

# %%
sns.countplot(x=df1.exang)
plt.show()

# %%
df1.exangC.value_counts().plot(kind="pie",autopct=("%1.1f%%"),shadow=True,figsize=(10,8))
plt.show()

# %%
df1.slopeC.value_counts()
# Out:
# Unsloping      142
# Flat           140
# Downsloping     21
# Name: slopeC, dtype: int64

# %%
sns.countplot(x=df1.slopeC)
plt.show()

# %%
df1.slopeC.value_counts().plot(kind="pie",autopct=("%1.1f%%"),shadow=True,figsize=(10,8))
plt.show()

# %%
df1.thal.value_counts()
# Out:
# 3    166
# 7    117
# 6     20
# Name: thal, dtype: int64

# %%
sns.countplot(x=df1.thalC)
plt.show()

# %%
df1.thalC.value_counts().plot(kind="pie",autopct=("%1.1f%%"),shadow=True,figsize=(10,8))
plt.show()

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
df1.num.value_counts()
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64

# %%
sns.countplot(x=df1.num)
plt.show()

# %%
df1.numC.value_counts().plot(kind="pie",autopct=("%1.1f%%"),shadow=True,figsize=(10,8))
plt.show()

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  ...  \
# 0   63    1   1       145   233    1        2      150      0      2.3  ...
# 1   67    1   4       160   286    0        2      108      1      1.5  ...
# 2   67    1   4       120   229    0        2      129      1      2.6  ...
# 3   37    1   3       130   250    0        0      187      0      3.5  ...
# 4   41    0   2       130   204    0        2      172      0      1.4  ...
#
#    ca  thal  num                   ageC    sexC            cpC exangC  \
# 0   0     6    0  Super Senior Citizens    Male         Stable     No
# 1   3     3    1  Super Senior Citizens    Male       Variants    Yes
# 2   2     7    1  Super Senior Citizens    Male       Variants    Yes
# 3   0     3    0       Seniour Citizens    Male  Microvascular     No
# 4   0     3    0       Seniour Citizens  Female       Unstable     No
#
#         slopeC              thalC      numC
# ...

# %% [markdown]
# # Multi-Variate Analysis

# %%
sns.barplot(x='sexC',y='trestbps',data=df1)
plt.title('Blood Pressure')
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Person's Resting Blood Pressure (mm Hg)", fontsize=12)
plt.show()

# %%
sns.barplot(x='sexC',y='chol',data=df1)
plt.title('Colestroal Level Based on Gender',fontsize=20)
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Colestroal", fontsize=15)
plt.show()

# %%
sns.barplot(x='numC',y='chol',data=df1)
plt.title('Colestroal VS Heart Disease',fontsize=20)
plt.xlabel('Hear Disease',fontsize=15)
plt.ylabel("Colestroal", fontsize=15)
plt.show()

# %%
sns.barplot(x='num',y='trestbps',data=df1)
plt.title('Blood Pressure VS Heart Disease',fontsize=20)
plt.xlabel('Heart Disease',fontsize=15)
plt.ylabel("Blood Pressure", fontsize=12)
plt.show()

# %%
sns.lineplot(x='age',y='trestbps',data=df1,color='g')
plt.title('Blood Pressure VS age',fontsize=20)
plt.xlabel('age',fontsize=15)
plt.ylabel("Blood Pressure", fontsize=15)
plt.show()

# %%
sns.lineplot(x='age',y='chol',data=df1,color='r')
plt.title('Cholestrol VS age',fontsize=20)
plt.xlabel('age',fontsize=15)
plt.ylabel("Cholestrol", fontsize=15)
plt.show()

# %%
sns.lineplot(x='age',y='oldpeak',data=df1,color='y')
plt.title('ST Depression VS age',fontsize=20)
plt.xlabel('age',fontsize=15)
plt.ylabel("ST Depression", fontsize=15)
plt.show()

# %%
sns.barplot(x='sex',y='oldpeak',data=df1,color='yellow')
plt.title('ST Depression VS sex',fontsize=20)
plt.xlabel('sex',fontsize=15)
plt.ylabel("ST Depression", fontsize=15)
plt.show()

# %%
sns.barplot(x='num',y='exang',data=df1,color='r')
plt.title('Exercise With Angina VS Heart Disease',fontsize=20)
plt.xlabel(' Heart Disease',fontsize=15)
plt.ylabel("Exercise With Angina", fontsize=15)
plt.show()

# %%
sns.barplot(x='sex',y='exang',data=df1,color='r')
plt.title('Exercise With Angina VS Gender',fontsize=20)
plt.xlabel('sex',fontsize=15)
plt.ylabel("Exercise With Angina", fontsize=15)
plt.show()

# %%
sns.barplot(x='fbs',y='sex',data=df,color='b')
plt.title('Fasting Blood Sugar VS Gender',fontsize=20)
plt.xlabel('sex',fontsize=15)
plt.ylabel("Fasting Blood Sugar", fontsize=15)
plt.show()

# %%
# Heatmab Creation Using Seaborn

plt.figure(figsize=(18,10))
sns.heatmap(df.corr(),annot=True,linewidths=3)
plt.show()

# %%
df.to_csv("heart.csv")

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
df1.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  ...  \
# 0   63    1   1       145   233    1        2      150      0      2.3  ...
# 1   67    1   4       160   286    0        2      108      1      1.5  ...
# 2   67    1   4       120   229    0        2      129      1      2.6  ...
# 3   37    1   3       130   250    0        0      187      0      3.5  ...
# 4   41    0   2       130   204    0        2      172      0      1.4  ...
#
#    ca  thal  num                   ageC    sexC            cpC exangC  \
# 0   0     6    0  Super Senior Citizens    Male         Stable     No
# 1   3     3    1  Super Senior Citizens    Male       Variants    Yes
# 2   2     7    1  Super Senior Citizens    Male       Variants    Yes
# 3   0     3    0       Seniour Citizens    Male  Microvascular     No
# 4   0     3    0       Seniour Citizens  Female       Unstable     No
#
#         slopeC              thalC      numC
# ...
